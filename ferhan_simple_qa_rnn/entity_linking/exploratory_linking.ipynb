# %%
import os
import sys
import argparse
import pickle
import math
import unicodedata
import pandas as pd

from fuzzywuzzy import fuzz
from nltk.tokenize.treebank import TreebankWordTokenizer
from nltk.corpus import stopwords

# %%
# arguments
index_entpath = "../indexes/entity_2M.pkl"
index_reachpath = "../indexes/reachability_2M.pkl"
index_namespath = "../indexes/names_2M.pkl"
ent_resultpath = "../entity_detection/query-text/val.txt"
rel_resultpath = "../relation_prediction/results/main-valid-results.txt"
outpath = "./tmp/results"

# %%
tokenizer = TreebankWordTokenizer()
stopwords = set(stopwords.words('english'))

def tokenize_text(text):
    tokens = tokenizer.tokenize(text)
    return tokens

def www2fb(in_str):
    if in_str.startswith("www.freebase.com"):
        return 'fb:%s' % (in_str.split('www.freebase.com/')[-1].replace('/', '.'))
    return in_str

def get_index(index_path):
    print("loading index from: {}".format(index_path))
    with open(index_path, 'rb') as f:
        index = pickle.load(f)
    return index

def strip_accents(text):
    return ''.join(c for c in unicodedata.normalize('NFKD', text) if unicodedata.category(c) != 'Mn')

# %%
def get_query_text(ent_resultpath):
    print("getting query text...")
    lineids = []
    id2query = {}
    notfound = 0
    with open(ent_resultpath, 'r') as f:
        for line in f:
            items = line.strip().split(" %%%% ")
            try:
                lineid = items[0].strip()
                query = items[1].strip()
                # mid = items[2].strip()
            except:
                # print("ERROR: line does not have >2 items  -->  {}".format(line.strip()))
                notfound += 1
                continue
            # print("{}   -   {}".format(lineid, query))
            lineids.append(lineid)
            id2query[lineid] = query
    print("notfound (empty query text): {}".format(notfound))
    return lineids, id2query

def get_relations(rel_resultpath):
    print("getting relations...")
    lineids = []
    id2rel = {}
    with open(rel_resultpath, 'r') as f:
        for line in f:
            items = line.strip().split(" %%%% ")
            lineid = items[0].strip()
            rel = items[1].strip()
            score = items[2].strip()
            # print("{}   -   {}".format(lineid, rel))
            lineids.append(lineid)
            id2rel[lineid] = rel
    return lineids, id2rel

# %%
def find_ngrams(input_list, n):
    ngrams = zip(*[input_list[i:] for i in range(n)])
    return set(ngrams)

# %%
def calc_tf_idf(query, cand_ent_name, cand_ent_count, num_entities, index_ent):
    query_terms = tokenize_text(query)
    doc_tokens = tokenize_text(cand_ent_name)
    common_terms = set(query_terms).intersection(set(doc_tokens))

    # len_intersection = len(common_terms)
    # len_union = len(set(query_terms).union(set(doc_tokens)))
    # tf = len_intersection / len_union
    tf = math.log10(cand_ent_count + 1)
    k1 = 0.5
    k2 = 0.5
    total_idf = 0
    for term in common_terms:
        df = len(index_ent[term])
        idf = math.log10( (num_entities - df + k1) / (df + k2) )
        total_idf += idf
    return tf * total_idf

def fuzzy_match(name, question):
    return fuzz.partial_ratio(name, question)

# %%
#outfile = open(os.path.join(outpath, "linking-results.txt"), 'w')
notfound_ent = 0
notfound_c = 0

index_ent = get_index(index_entpath)
num_entities_fbsubset = 1959820  # 2M - 1959820 , 5M - 1972702
# Out:
# loading index from: ../indexes/entity_2M.pkl

# %%
index_names = get_index(index_namespath)
# Out:
# loading index from: ../indexes/names_2M.pkl

# %%
index_reach = get_index(index_reachpath)
# Out:
# loading index from: ../indexes/reachability_2M.pkl

# %%
def pick_best_name(question, names_list):
    best_score = None
    best_name = None
    for name in names_list:
        score =  fuzz.ratio(name, question)
        if best_score == None or score > best_score:
            best_score = score
            best_name = name

    return best_name

# %%
rel_lineids, id2rel = get_relations(rel_resultpath)
ent_lineids, id2query = get_query_text(ent_resultpath)  # ent_lineids may have some examples missing
# Out:
# getting relations...
# getting query text...
# notfound (empty query text): 0

# %%
def get_questions(datapath):
    print("getting questions...")
    id2question = {}
    with open(datapath, 'r') as f:
        for line in f:
            items = line.strip().split("\t")
            lineid = items[0].strip()
            sub = items[1].strip()
            pred = items[2].strip()
            obj = items[3].strip()
            question = items[4].strip()
            # print("{}   -   {}".format(lineid, question))
            if lineid.startswith("valid"):
                id2question[lineid] = (sub, pred, question)
    return id2question

datapath = "../data/SimpleQuestions_v2_modified/all.txt"
id2question = get_questions(datapath)
print(id2question['valid-1'])
# Out:
# getting questions...
# ('fb:m.0f3xg_', 'fb:symbols.namesake.named_after', 'Who was the trump ocean club international hotel and tower named after')

# %%
def get_docs(query):
    docids = index_ent[query]
    docs = []
    for id in docids:
        try:
            docs.append( (id, index_names[id]) )
        except:
            continue
    return docs

# %%
print(len(id2query))
print(len(id2rel))
# Out:
# 10845
# 10845

# %%
index_ent["carlos"]
# Out:
# {'fb:m.02rfnbr',
#  'fb:m.0b6j1hb',
#  'fb:m.0fvpvq',
#  'fb:m.0ksvtcp',
#  'fb:m.050vqm',
#  'fb:m.05q5xv8',
#  'fb:m.0ct040',
#  'fb:m.0343fl',
#  'fb:m.0crsgh3',
#  'fb:m.02rtln4',
#  'fb:m.0pd9syf',
#  'fb:m.04cxkbv',
#  'fb:m.0gfrl81',
#  'fb:m.01wm909',
#  'fb:m.0dgpc72',
#  'fb:m.0rf67jw',
#  'fb:m.09c2n2',
#  'fb:m.05pt8m',
#  'fb:m.03cggsq',
#  'fb:m.0gvrcn9',
#  'fb:m.0bbxwws',
#  'fb:m.0hzrbzc',
#  'fb:m.099tjm',
#  'fb:m.0bxzcqv',
#  'fb:m.0y4t4wr',
#  'fb:m.0b6mljj',
#  'fb:m.04x5g_',
#  'fb:m.04n35ks',
#  'fb:m.0x0fb8l',
#  'fb:m.0bwkh5g',
#  'fb:m.0qgr824',
#  'fb:m.01jb5mb',
#  'fb:m.06w9sy5',
#  'fb:m.0qpwrxv',
#  'fb:m.02810z6',
#  'fb:m.0l1l3',
#  'fb:m.0gccpz7',
#  'fb:m.0fw6_f',
#  'fb:m.05b30dm',
#  'fb:m.0f12v7d',
#  'fb:m.02x2sc',
#  'fb:m.0bvqf0t',
#  'fb:m.02vltgw',
#  'fb:m.02vydb0',
#  'fb:m.054wb66',
#  'fb:m.02rhp9j',
#  'fb:m.0cjlwk',
#  'fb:m.0462gmv',
#  'fb:m.0d0qws',
#  'fb:m.0fzbtm',
#  'fb:m.03grzh3',
#  'fb:m.0gfrmff',
#  'fb:m.064n6q',
#  'fb:m.02wb41k',
#  'fb:m.0crv7xt',
#  'fb:m.0gn1zw',
#  'fb:m.0bgr2k',
#  'fb:m.09gqd5q',
#  'fb:m.043lx1y',
#  'fb:m.0byzkc',
#  'fb:m.03243y',
#  'fb:m.0tld9db',
#  'fb:m.0bm93tg',
#  'fb:m.02qm6tx',
#  'fb:m.0ds0msq',
#  'fb:m.02x6965',
#  'fb:m.0gfhzpv',
#  'fb:m.01rvrn',
#  'fb:m.01pllx',
#  'fb:m.01pjzjn',
#  'fb:m.086m30',
#  'fb:m.05p5nbk',
#  'fb:m.0mv9jzs',
#  'fb:m.0c79s3',
#  'fb:m.0v4wcl7',
#  'fb:m.0g8ljn',
#  'fb:m.0hgn35p',
#  'fb:m.02vw8nb',
#  'fb:m.053yq_',
#  'fb:m.03h5n87',
#  'fb:m.0_vprmx',
#  'fb:m.05p2l8b',
#  'fb:m.0368nhg',
#  'fb:m.0873mf',
#  'fb:m.0dl__d',
#  'fb:m.0ymtdn',
#  'fb:m.01vzk59',
#  'fb:m.0jt45kw',
#  'fb:m.09gpdyv',
#  'fb:m.01jb8mq',
#  'fb:m.0l9vv71',
#  'fb:m.01ppp_',
#  'fb:m.0g858h',
#  'fb:m.0pkzgwf',
#  'fb:m.032p24',
#  'fb:m.05zrgv1',
#  'fb:m.03gxx87',
#  'fb:m.02vlnbt',
#  'fb:m.0f9kcxr',
#  'fb:m.02rbfz3',
#  'fb:m.03m79mr',
#  'fb:m.0641tsk',
#  'fb:m.03d64m6',
#  'fb:m.0bmfyw9',
#  'fb:m.05mx1y',
#  'fb:m.0h3dxk1',
#  'fb:m.0jz1xm',
#  'fb:m.01s86h',
#  'fb:m.0dzv7j',
#  'fb:m.085zq8',
#  'fb:m.04q272x',
#  'fb:m.03m7yzb',
#  'fb:m.08dwxy',
#  'fb:m.026zc_k',
#  'fb:m.03cc6vt',
#  'fb:m.02jkh6',
#  'fb:m.0gc4bxl',
#  'fb:m.0g6f8cj',
#  'fb:m.0n9l2w1',
#  'fb:m.0br_lsx',
#  'fb:m.0n5cv0g',
#  'fb:m.04fzzbm',
#  'fb:m.0vzh4',
#  'fb:m.016883',
#  'fb:m.01q9y4k',
#  'fb:m.02_qfv',
#  'fb:m.04brs0',
#  'fb:m.0b75r6j',
#  'fb:m.04w_c6',
#  'fb:m.06zp5hg',
#  'fb:m.0fmp75',
#  'fb:m.0ndst8p',
#  'fb:m.0hp7sgx',
#  'fb:m.0h1pvcb',
#  'fb:m.0hnv4qd',
#  'fb:m.02qhbr2',
#  'fb:m.049l6cv',
#  'fb:m.02pkrzn',
#  'fb:m.0j2lrh0',
#  'fb:m.0gc3z30',
#  'fb:m.0rqgf3j',
#  'fb:m.06zmgwv',
#  'fb:m.0jvbxvj',
#  'fb:m.01q2k4x',
#  'fb:m.02pysml',
#  'fb:m.0h53d4p',
#  'fb:m.0d7_4',
#  'fb:m.03cblzx',
#  'fb:m.0r9szp5',
#  'fb:m.01wjgzr',
#  'fb:m.0jsrfm3',
#  'fb:m.0dsccwh',
#  'fb:m.0fp4y_',
#  'fb:m.06w3mp2',
#  'fb:m.02w1tdb',
#  'fb:m.05v9gyy',
#  'fb:m.0gmltkj',
#  'fb:m.0bvcbr1',
#  'fb:m.04308z9',
#  'fb:m.0fyv0',
#  'fb:m.05_60xn',
#  'fb:m.04rvzt',
#  'fb:m.03mn71',
#  'fb:m.0fnrlb',
#  'fb:m.0dfyj60',
#  'fb:m.020xxr',
#  'fb:m.0fkvdx',
#  'fb:m.0cgj_wk',
#  'fb:m.0hr886q',
#  'fb:m.0cz1yh',
#  'fb:m.01t_jkh',
#  'fb:m.0h7mvt9',
#  'fb:m.0_ysjw9',
#  'fb:m.05l91f',
#  'fb:m.01rvcq6',
#  'fb:m.0wp8mcz',
#  'fb:m.0yq43s6',
#  'fb:m.0ks9w4',
#  'fb:m.04q2hjd',
#  'fb:m.01p8h_q',
#  'fb:m.03h1fn5',
#  'fb:m.03cmfl5',
#  'fb:m.05mxryq',
#  'fb:m.056698',
#  'fb:m.02z5g6l',
#  'fb:m.0k24l3',
#  'fb:m.069y2b',
#  'fb:m.0x171dv',
#  'fb:m.02psk8v',
#  'fb:m.0y8c__l',
#  'fb:m.016n_c',
#  'fb:m.04lflcz',
#  'fb:m.0jq6f0t',
#  'fb:m.0j7nh3p',
#  'fb:m.0d_2kv',
#  'fb:m.03d7qrf',
#  'fb:m.0k083g',
#  'fb:m.0vp3m68',
#  'fb:m.01w43dp',
#  'fb:m.03ccg5x',
#  'fb:m.02xv2t',
#  'fb:m.0j9pm6l',
#  'fb:m.01srzq1',
#  'fb:m.0hh2jdy',
#  'fb:m.0gvhnmw',
#  'fb:m.05pxzh6',
#  'fb:m.04fprx',
#  'fb:m.04120vy',
#  'fb:m.0gl3y5z',
#  'fb:m.02ql17c',
#  'fb:m.0bs1nvj',
#  'fb:m.01w_f9s',
#  'fb:m.0n918tt',
#  'fb:m.0_skgc1',
#  'fb:m.04ljsfy',
#  'fb:m.0gbyp4p',
#  'fb:m.0cj59k_',
#  'fb:m.099ksc',
#  'fb:m.01l7jqy',
#  'fb:m.04y6nzy',
#  'fb:m.0bpj7sh',
#  'fb:m.0h4cg9',
#  'fb:m.0bsvl6',
#  'fb:m.03d11rd',
#  'fb:m.0t_7c3h',
#  'fb:m.03d8md6',
#  'fb:m.05pf2q',
#  'fb:m.09yhfm',
#  'fb:m.026450b',
#  'fb:m.03m64hr',
#  'fb:m.0bqsdrs',
#  'fb:m.0dgpry8',
#  'fb:m.06rjxg',
#  'fb:m.05y0gp',
#  'fb:m.0w6twq6',
#  'fb:m.0bs36g5',
#  'fb:m.05cw32',
#  'fb:m.0rntz4g',
#  'fb:m.06zlybp',
#  'fb:m.032szkw',
#  'fb:m.0h6s2_',
#  'fb:m.0c819j',
#  'fb:m.0zg320n',
#  'fb:m.080k_x',
#  'fb:m.0cl3xhl',
#  'fb:m.057g2x',
#  'fb:m.0c5ltt',
#  'fb:m.02vxvkw',
#  'fb:m.01mm31d',
#  'fb:m.05pb754',
#  'fb:m.0zn308d',
#  'fb:m.0gchqt_',
#  'fb:m.064k3lc',
#  'fb:m.0bh9qq3',
#  'fb:m.04ghc43',
#  'fb:m.0jwps9',
#  'fb:m.09gfxsm',
#  'fb:m.03m85dm',
#  'fb:m.032wc0',
#  'fb:m.0bdtb93',
#  'fb:m.02r_7_v',
#  'fb:m.08lrqt',
#  'fb:m.0_gfc3v',
#  'fb:m.0nby3zv',
#  'fb:m.02x5rzh',
#  'fb:m.0p79wf8',
#  'fb:m.026khx6',
#  'fb:m.0ks7xv',
#  'fb:m.05b5hm6',
#  'fb:m.0jxcc_9',
#  'fb:m.0j7ch6l',
#  'fb:m.03c53qc',
#  'fb:m.0h2z4c',
#  'fb:m.027f7pg',
#  'fb:m.0j67cl4',
#  'fb:m.07tc03',
#  'fb:m.09gcszr',
#  'fb:m.04455p',
#  'fb:m.0swl40w',
#  'fb:m.0vpl7qs',
#  'fb:m.0k059v8',
#  'fb:m.05fcc38',
#  'fb:m.0dd9xd7',
#  'fb:m.05hdhj',
#  'fb:m.0jxwmjx',
#  'fb:m.09g50',
#  'fb:m.03cgjpj',
#  'fb:m.07j0xv',
#  'fb:m.0pcq05k',
#  'fb:m.051kw2',
#  'fb:m.0vxs8mc',
#  'fb:m.02q0fr9',
#  'fb:m.02wys_c',
#  'fb:m.01vrpnp',
#  'fb:m.0q4fdrc',
#  'fb:m.05szzpt',
#  'fb:m.0n9q66q',
#  'fb:m.077p_2',
#  'fb:m.0gcyc3k',
#  'fb:m.027szqp',
#  'fb:m.0_yw3rf',
#  'fb:m.02vlr4l',
#  'fb:m.047nwxs',
#  'fb:m.0qm5f1s',
#  'fb:m.0cgqs9g',
#  'fb:m.03qmg1_',
#  'fb:m.0gg688v',
#  'fb:m.03y8_z6',
#  'fb:m.0qt3tmm',
#  'fb:m.02z55y5',
#  'fb:m.0_80h8',
#  'fb:m.01sbykw',
#  'fb:m.09zkqb',
#  'fb:m.0416x1g',
#  'fb:m.025ywlv',
#  'fb:m.026gj8j',
#  'fb:m.06_y3kg',
#  'fb:m.0n51371',
#  'fb:m.03c03kz',
#  'fb:m.0gb_2s1',
#  'fb:m.09ry6k',
#  'fb:m.0ztnwnw',
#  'fb:m.01s_b29',
#  'fb:m.0ctww9',
#  'fb:m.0vxpdzx',
#  'fb:m.0lz0_xt',
#  'fb:m.02w7kw2',
#  'fb:m.05c95x',
#  'fb:m.0crzp4v',
#  'fb:m.0jwlc1l',
#  'fb:m.03clwb1',
#  'fb:m.0gysj_q',
#  'fb:m.0gc1t3h',
#  'fb:m.0pdkw2f',
#  'fb:m.0yf_12k',
#  'fb:m.0dvvny',
#  'fb:m.0329_6',
#  'fb:m.0ytg845',
#  'fb:m.05w14v',
#  'fb:m.0r94fpw',
#  'fb:m.0d58rm',
#  'fb:m.04kr0',
#  'fb:m.0279681',
#  'fb:m.03ql8fp',
#  'fb:m.0t5l5z3',
#  'fb:m.02jlx7',
#  'fb:m.0cj3c_b',
#  'fb:m.01mbf9d',
#  'fb:m.0cmq6y',
#  'fb:m.0293001',
#  'fb:m.0r5xy',
#  'fb:m.04792jr',
#  'fb:m.0gyb330',
#  'fb:m.01scmm0',
#  'fb:m.082l9t',
#  'fb:m.0gg28j',
#  'fb:m.01ldmj',
#  'fb:m.0_qpxyl',
#  'fb:m.0vp6tvj',
#  'fb:m.02x5w_t',
#  'fb:m.04f_fqz',
#  'fb:m.0pyq_',
#  'fb:m.0ql4b4z',
#  'fb:m.04lqxhg',
#  'fb:m.032bs0',
#  'fb:m.0636sw',
#  'fb:m.083tfh',
#  'fb:m.02r188p',
#  'fb:m.02x3z6j',
#  'fb:m.0j3wvsc',
#  'fb:m.0bqp6q',
#  'fb:m.0bv_lgc',
#  'fb:m.0465qkn',
#  'fb:m.07bnsk',
#  'fb:m.04mkhj6',
#  'fb:m.0407wq0',
#  'fb:m.0_g4z6s',
#  'fb:m.02vs2xx',
#  'fb:m.0j9f_hs',
#  'fb:m.09k6g_2',
#  'fb:m.078q2m',
#  'fb:m.03d4lx',
#  'fb:m.064160k',
#  'fb:m.01v8zdm',
#  'fb:m.04j769',
#  'fb:m.03c3wwk',
#  'fb:m.0h4yp86',
#  'fb:m.0j_ygml',
#  'fb:m.02rjs3y',
#  'fb:m.02pnw5b',
#  'fb:m.0ft94z',
#  'fb:m.0gfgv1v',
#  'fb:m.05ng4f',
#  'fb:m.01lg_s',
#  'fb:m.03s9dn',
#  'fb:m.0jvtqgn',
#  'fb:m.0ffwjsf',
#  'fb:m.0gcbw7y',
#  'fb:m.0llljnk',
#  'fb:m.0j6j1ff',
#  'fb:m.05zzzws',
#  'fb:m.0gyvwqh',
#  'fb:m.0cgzjxv',
#  'fb:m.0h6shc',
#  'fb:m.02pk8xh',
#  'fb:m.026jpyz',
#  'fb:m.0463gg2',
#  'fb:m.0yn93g9',
#  'fb:m.06zlw0c',
#  'fb:m.0x1lp1r',
#  'fb:m.0jvt7r9',
#  'fb:m.026_fsn',
#  'fb:m.013rdf',
#  'fb:m.043l3wr',
#  'fb:m.0g7xb2s',
#  'fb:m.02ryrd3',
#  'fb:m.0s8vq8x',
#  'fb:m.0262_lw',
#  'fb:m.0cgh3ry',
#  'fb:m.04cllbg',
#  'fb:m.020g89',
#  'fb:m.08hm3f',
#  'fb:m.0cqksk',
#  'fb:m.0k0vq4v',
#  'fb:m.0yyhgrf',
#  'fb:m.0kt84d',
#  'fb:m.094xxb',
#  'fb:m.01k2wy9',
#  'fb:m.0dfr9',
#  'fb:m.04z_lxf',
#  'fb:m.0j_j6kx',
#  'fb:m.02rntpb',
#  'fb:m.0ckvsk',
#  'fb:m.09rt29l',
#  'fb:m.047ldr8',
#  'fb:m.0zcyt98',
#  'fb:m.0f81sk',
#  'fb:m.0dnsww',
#  'fb:m.07b_8m',
#  'fb:m.01l7jvc',
#  'fb:m.0gvsqks',
#  'fb:m.0274nqt',
#  'fb:m.0gtxlzf',
#  'fb:m.03cl3fp',
#  'fb:m.04y9r88',
#  'fb:m.0mx66gv',
#  'fb:m.0dt27l',
#  'fb:m.02w02z7',
#  'fb:m.047dztm',
#  'fb:m.0bb5gkg',
#  'fb:m.05zlws8',
#  'fb:m.0bgbq8b',
#  'fb:m.03m1dh',
#  'fb:m.0ypyl2t',
#  'fb:m.0h6y6',
#  'fb:m.0b71j2',
#  'fb:m.0fn4sg',
#  'fb:m.0t5t77c',
#  'fb:m.03c4n1d',
#  'fb:m.02plytt',
#  'fb:m.0gdkpcb',
#  'fb:m.03cfnqn',
#  'fb:m.0jwb4lb',
#  'fb:m.0466dpg',
#  'fb:m.0jt34d9',
#  'fb:m.04p4cdb',
#  'fb:m.0hzpv1p',
#  'fb:m.0yxb561',
#  'fb:m.01jb7k2',
#  'fb:m.02vwrb8',
#  'fb:m.02mzy_',
#  'fb:m.093dxqx',
#  'fb:m.06w979p',
#  'fb:m.05q5j09',
#  'fb:m.063_8jv',
#  'fb:m.0gbv0b1',
#  'fb:m.08077t3',
#  'fb:m.0k8bmbt',
#  'fb:m.05h42dm',
#  'fb:m.0knwgrh',
#  'fb:m.0g9z15p',
#  'fb:m.02wb0vs',
#  'fb:m.06pkhx',
#  'fb:m.09_zf6',
#  'fb:m.01w8ss9',
#  'fb:m.0j50vsf',
#  'fb:m.02z4prw',
#  'fb:m.03h4js4',
#  'fb:m.0cr61kc',
#  'fb:m.0gcf7z1',
#  'fb:m.0bvsnmb',
#  'fb:m.0cb615',
#  'fb:m.0bgrkp',
#  'fb:m.03yz63p',
#  'fb:m.0gbwvkw',
#  'fb:m.0_vgddq',
#  'fb:m.027v4rr',
#  'fb:m.0gc84gc',
#  'fb:m.05h4zpg',
#  'fb:m.0bwb2jp',
#  'fb:m.02ntqk',
#  'fb:m.01l7k97',
#  'fb:m.027zzgz',
#  'fb:m.03chj4n',
#  'fb:m.0bfdybx',
#  'fb:m.0hnschr',
#  'fb:m.03cpl18',
#  'fb:m.050lg7',
#  'fb:m.01hd889',
#  'fb:m.0_qt31z',
#  'fb:m.0cf8pn',
#  'fb:m.02ygr1',
#  'fb:m.0dndvm1',
#  'fb:m.07771l',
#  'fb:m.0jxrpm',
#  'fb:m.026kfbb',
#  'fb:m.01v_nm',
#  'fb:m.0qt4fzk',
#  'fb:m.05n02xl',
#  'fb:m.07tw35',
#  'fb:m.0hp1vy3',
#  'fb:m.0dgptfg',
#  'fb:m.0crsqxj',
#  'fb:m.026j2gs',
#  'fb:m.02_s_g',
#  'fb:m.0d65wd',
#  'fb:m.0x2_kjb',
#  'fb:m.01jk_s1',
#  'fb:m.0506j8',
#  'fb:m.0g5qb83',
#  'fb:m.0gbxvs6',
#  'fb:m.028srd',
#  'fb:m.0gm2bhf',
#  'fb:m.02x992h',
#  'fb:m.0523yx5',
#  'fb:m.0zd51m1',
#  'fb:m.04jl6l2',
#  'fb:m.0gxlf3',
#  'fb:m.032pg9',
#  'fb:m.0h2m7vl',
#  'fb:m.071t5x',
#  'fb:m.02vwtc7',
#  'fb:m.0nf0gg_',
#  'fb:m.0b3370',
#  'fb:m.030tb6',
#  'fb:m.06354c',
#  'fb:m.04sgbh',
#  'fb:m.05b11zj',
#  'fb:m.0h1cs9t',
#  'fb:m.0v_q5y1',
#  'fb:m.0818bv',
#  'fb:m.02qgrjt',
#  'fb:m.0qgq8h6',
#  'fb:m.02q0fvd',
#  'fb:m.03ycxbd',
#  'fb:m.0c7w2w',
#  'fb:m.0cn_s49',
#  'fb:m.08qbrg',
#  'fb:m.03h0pyq',
#  'fb:m.01g6nlc',
#  'fb:m.0h4p14k',
#  'fb:m.04n6bv0',
#  'fb:m.09v2l7b',
#  'fb:m.0cl0gp',
#  'fb:m.02qfcy0',
#  'fb:m.0czblvb',
#  'fb:m.06y8r9',
#  'fb:m.0gpnwj',
#  'fb:m.06yknb',
#  'fb:m.09glffl',
#  'fb:m.02vtvx9',
#  'fb:m.03gkyq',
#  'fb:m.0y6c5kz',
#  'fb:m.01m3b3p',
#  'fb:m.09vbk7',
#  'fb:m.0g4jf61',
#  'fb:m.028b229',
#  'fb:m.0plwnqp',
#  'fb:m.0vb9n5h',
#  'fb:m.09c29r',
#  'fb:m.0lq1y2n',
#  'fb:m.0bk79b',
#  'fb:m.0bvb8qy',
#  'fb:m.0552s5',
#  'fb:m.0n3j_cq',
#  'fb:m.02839yz',
#  'fb:m.0gc2lq0',
#  'fb:m.0164bwm',
#  'fb:m.06rmbl',
#  'fb:m.04n2_tw',
#  'fb:m.0h8dw9c',
#  'fb:m.0h1j1l0',
#  'fb:m.079ptv',
#  'fb:m.0gmlv1g',
#  'fb:m.0gybjgv',
#  'fb:m.05b_lys',
#  'fb:m.0wpbp8l',
#  'fb:m.02pwmj7',
#  'fb:m.0pccxk6',
#  'fb:m.05b1wp8',
#  'fb:m.0n5wz74',
#  'fb:m.0bdtwg',
#  'fb:m.09y7rz',
#  'fb:m.01g5kh1',
#  'fb:m.0fqffz',
#  'fb:m.018c54',
#  'fb:m.02z4zrd',
#  'fb:m.01l7jcq',
#  'fb:m.0nf14ky',
#  'fb:m.061y52',
#  'fb:m.04f17qr',
#  'fb:m.037n_q',
#  'fb:m.02qh5gj',
#  'fb:m.0hznx4v',
#  'fb:m.0g_xgm',
#  'fb:m.0y72ht9',
#  'fb:m.0dbj4q',
#  'fb:m.0bdqvp',
#  'fb:m.0gcp70t',
#  'fb:m.0j3zdhg',
#  'fb:m.0bffn0',
#  'fb:m.0ftx5k',
#  'fb:m.0bdq00',
#  'fb:m.025zq7k',
#  'fb:m.04nl9g1',
#  'fb:m.0bfbmt3',
#  'fb:m.04y9s0r',
#  'fb:m.03wcr9r',
#  'fb:m.01dtnl',
#  'fb:m.0cggy3q',
#  'fb:m.03hjr4y',
#  'fb:m.02m__8',
#  'fb:m.03c78l_',
#  'fb:m.06ykv4',
#  'fb:m.03ycx90',
#  'fb:m.0zfwld_',
#  'fb:m.0d72nv',
#  'fb:m.01bs1p',
#  'fb:m.02w8_8r',
#  'fb:m.05kkjn',
#  'fb:m.01qgq0z',
#  'fb:m.01nkbwm',
#  'fb:m.03nv5gx',
#  'fb:m.03c13k_',
#  'fb:m.0jyd8s',
#  'fb:m.04crkxk',
#  'fb:m.0gg6zk3',
#  'fb:m.06wb5q7',
#  'fb:m.0n5cwlc',
#  'fb:m.0rqjl6b',
#  'fb:m.04p1ct',
#  'fb:m.043k1rl',
#  'fb:m.01vwdq',
#  'fb:m.0bhgxc8',
#  'fb:m.02q85tf',
#  'fb:m.0djn17',
#  'fb:m.02bfyx',
#  'fb:m.02wbcqp',
#  'fb:m.03yk54c',
#  'fb:m.0dscjkp',
#  'fb:m.0byshr2',
#  'fb:m.0k7gv7b',
#  'fb:m.0y47qnw',
#  'fb:m.0zmvsdf',
#  'fb:m.02wx9x',
#  'fb:m.03crtk3',
#  'fb:m.01jbt6y',
#  'fb:m.0g4p33q',
#  'fb:m.086yr',
#  'fb:m.0k0tctd',
#  'fb:m.03y9nfg',
#  'fb:m.0kvjx3',
#  'fb:m.0tk4sr2',
#  'fb:m.02z299z',
#  'fb:m.0fylzf',
#  'fb:m.09zx9p0',
#  'fb:m.08_n9s',
#  'fb:m.02vrqz8',
#  'fb:m.0chtg3x',
#  'fb:m.03rprm',
#  'fb:m.0h7pt8q',
#  'fb:m.0gy11f4',
#  'fb:m.02rcmlk',
#  'fb:m.04g15tj',
#  'fb:m.0bh6wcv',
#  'fb:m.02wbkxp',
#  'fb:m.0h3yly3',
#  'fb:m.0ryln9h',
#  'fb:m.0hnph1g',
#  'fb:m.0qhgs18',
#  'fb:m.03cqhkm',
#  'fb:m.0lmk9pb',
#  'fb:m.0qjj0',
#  'fb:m.05nf93',
#  'fb:m.094g0r',
#  'fb:m.04sfc5f',
#  'fb:m.024kx8',
#  'fb:m.0p5_cyw',
#  'fb:m.03x_kv8',
#  'fb:m.0h2m7b',
#  'fb:m.0tlb5w9',
#  'fb:m.026vb99',
#  'fb:m.0927w6',
#  'fb:m.0g56ynk',
#  'fb:m.0knt66v',
#  'fb:m.0g9mdvs',
#  'fb:m.026qt7h',
#  'fb:m.077mdt',
#  'fb:m.0k4ht7',
#  'fb:m.075xnpx',
#  'fb:m.03cfw3x',
#  'fb:m.012y7x',
#  'fb:m.03h3jdd',
#  'fb:m.026979f',
#  'fb:m.027c47_',
#  'fb:m.04zyll6',
#  'fb:m.0w_zthc',
#  'fb:m.0hhv_9w',
#  'fb:m.0f6dsfk',
#  'fb:m.03yfzv1',
#  'fb:m.02qjqkx',
#  'fb:m.0c_gkq',
#  'fb:m.0g5r1mv',
#  'fb:m.04q6qbv',
#  'fb:m.04nkpqv',
#  'fb:m.03hgvst',
#  'fb:m.02r5t9d',
#  'fb:m.0k1bh3',
#  'fb:m.09hn9l',
#  'fb:m.0j49z4_',
#  'fb:m.0bxl72g',
#  'fb:m.0wylmyh',
#  'fb:m.03hfww8',
#  'fb:m.0h7nghy',
#  'fb:m.0j8fv7n',
#  'fb:m.04jtkk',
#  'fb:m.0n1_8vv',
#  'fb:m.03cl496',
#  'fb:m.028b3_5',
#  'fb:m.0463rqg',
#  'fb:m.0cbpxs',
#  'fb:m.05rv8p',
#  'fb:m.0x10yx8',
#  'fb:m.0s960lm',
#  'fb:m.0vv58b7',
#  'fb:m.04f2x70',
#  'fb:m.065yt9g',
#  'fb:m.05wl2py',
#  'fb:m.0wqfv3l',
#  'fb:m.05sy9ss',
#  'fb:m.0crts2b',
#  'fb:m.07lmtcc',
#  'fb:m.0fpp7jm',
#  'fb:m.0jzj4dk',
#  'fb:m.01jl45h',
#  'fb:m.03m6grn',
#  'fb:m.06zm_cv',
#  'fb:m.0xnc7jd',
#  'fb:m.0ktdrf',
#  'fb:m.05mycvd',
#  'fb:m.0ncxpzt',
#  'fb:m.0jtny0',
#  'fb:m.02vnbts',
#  'fb:m.087g7q',
#  'fb:m.0gy5qz',
#  'fb:m.08xk6b',
#  'fb:m.0rysllt',
#  'fb:m.0h1d93n',
#  'fb:m.05p7lwg',
#  'fb:m.09rhxfg',
#  'fb:m.09gfhjt',
#  'fb:m.0f0y2k6',
#  'fb:m.02vpgfc',
#  'fb:m.0gbx_fr',
#  'fb:m.0h17fg',
#  'fb:m.0j9yfr6',
#  'fb:m.03hwp6',
#  'fb:m.0pdkvz6',
#  'fb:m.01_8_',
#  'fb:m.0h_d5sd',
#  'fb:m.047cdpb',
#  'fb:m.02qlj0h',
#  'fb:m.0hg_7rb',
#  'fb:m.027hcwl',
#  'fb:m.04_0jk3',
#  'fb:m.075skt4',
#  'fb:m.02q9_m4',
#  'fb:m.05xh4r0',
#  'fb:m.0ndcft4',
#  'fb:m.027gfnr',
#  'fb:m.0sl248f',
#  'fb:m.0j5d7qb',
#  'fb:m.0q2__f',
#  'fb:m.07gtt9',
#  'fb:m.0vxf15w',
#  'fb:m.03mzr_',
#  'fb:m.0btlt1',
#  'fb:m.0ymfdw0',
#  'fb:m.01rv540',
#  'fb:m.0h7nf3b',
#  'fb:m.0j2mmxr',
#  'fb:m.04mw1gx',
#  'fb:m.02phhs4',
#  'fb:m.0h77dp2',
#  'fb:m.0d1pg1',
#  'fb:m.0w33rj6',
#  'fb:m.0gvsxbj',
#  'fb:m.03nxdj2',
#  'fb:m.0f70_q',
#  'fb:m.0r4r3pk',
#  'fb:m.02wxxpn',
#  'fb:m.02yt_p',
#  'fb:m.0zb4tp7',
#  'fb:m.0jwwm5h',
#  'fb:m.0hzrhcm',
#  'fb:m.027nhr6',
#  'fb:m.0l7xkbr',
#  'fb:m.063_bw4',
#  'fb:m.0bv9lj',
#  'fb:m.05c1sd3',
#  'fb:m.02qhgnx',
#  'fb:m.0gnd0_',
#  'fb:m.0n4qqw1',
#  'fb:m.0_7032_',
#  'fb:m.07844v',
#  'fb:m.0g4gqq',
#  'fb:m.01q_7_b',
#  'fb:m.02pzfgc',
#  'fb:m.027wcfr',
#  'fb:m.0bv87q',
#  'fb:m.04816b',
#  'fb:m.0k78822',
#  'fb:m.0bffy6',
#  'fb:m.0gsyvv0',
#  'fb:m.0808rb2',
#  'fb:m.0k_69',
#  'fb:m.01hrbxh',
#  'fb:m.0t_dcs_',
#  'fb:m.0zgdb7j',
#  'fb:m.0g4xc4f',
#  'fb:m.0f48st',
#  'fb:m.0k1jnmc',
#  'fb:m.0v25p_9',
#  'fb:m.0krqx5',
#  'fb:m.02r8j92',
#  'fb:m.0ghcbj',
#  'fb:m.080mv0m',
#  'fb:m.0lwnk3l',
#  'fb:m.02w3l0h',
#  'fb:m.06jzvm',
#  'fb:m.07s9yzp',
#  'fb:m.0cc8sfy',
#  'fb:m.0405pz0',
#  'fb:m.0287ky',
#  'fb:m.02pgzcz',
#  'fb:m.0pl4rp4',
#  'fb:m.02q0wnp',
#  'fb:m.08m6hs',
#  'fb:m.028606x',
#  'fb:m.01yflc',
#  'fb:m.064qj_1',
#  'fb:m.03ns4b2',
#  'fb:m.0g5r44s',
#  'fb:m.0z663jg',
#  'fb:m.0s9k0w4',
#  'fb:m.047rryn',
#  'fb:m.0h2m976',
#  'fb:m.0b8v1q',
#  'fb:m.064qmkf',
#  'fb:m.02prw_d',
#  'fb:m.0w7p4x1',
#  'fb:m.04ct002',
#  'fb:m.07jg3g',
#  'fb:m.0275lwp',
#  'fb:m.02wz137',
#  'fb:m.0b3h_g',
#  'fb:m.01vz7ff',
#  'fb:m.080bffz',
#  'fb:m.0k8qzvt',
#  'fb:m.0fp_h0x',
#  'fb:m.0ds8brs',
#  'fb:m.09m7by',
#  'fb:m.0gd2yf8',
#  'fb:m.0glphxj',
#  'fb:m.0j6tb_k',
#  'fb:m.0jzl1m4',
#  'fb:m.011hjj',
#  'fb:m.07k93nc',
#  'fb:m.0n64_hk',
#  'fb:m.0ds13p',
#  'fb:m.03ck650',
#  'fb:m.075yc9',
#  'fb:m.047s6kn',
#  'fb:m.0kj5f4d',
#  'fb:m.06pctwm',
#  'fb:m.0_qn8vf',
#  'fb:m.0fqq2mm',
#  'fb:m.05p5_n9',
#  'fb:m.0ngk659',
#  'fb:m.04p6379',
#  'fb:m.02rp7ym',
#  'fb:m.036vhn',
#  'fb:m.0gc8g9m',
#  'fb:m.04gnhvl',
#  'fb:m.0h29_0',
#  'fb:m.0cwdyv',
#  'fb:m.09zl5j',
#  'fb:m.0mxzgzp',
#  'fb:m.0g_vjs',
#  'fb:m.05w4n_',
#  'fb:m.0jsszsq',
#  'fb:m.0b_khsh',
#  'fb:m.05tq5f',
#  'fb:m.01npxj2',
#  'fb:m.02vzz4g',
#  'fb:m.0806lbm',
#  'fb:m.0jz5n87',
#  'fb:m.0qzf39_',
#  'fb:m.0dt0d85',
#  'fb:m.04ghf50',
#  'fb:m.04mxclz',
#  'fb:m.0crymjr',
#  'fb:m.04_8dby',
#  'fb:m.0v312ww',
#  'fb:m.03gyh0b',
#  'fb:m.071rhy',
#  'fb:m.0dm37s8',
#  'fb:m.052_tsh',
#  'fb:m.0h7ldzn',
#  'fb:m.0gdgvf',
#  'fb:m.0_qpvg8',
#  'fb:m.01djvl',
#  'fb:m.0byy2sw',
#  'fb:m.03h0ksq',
#  'fb:m.0t5pcd5',
#  'fb:m.0b751yc',
#  'fb:m.05fbjyd',
#  'fb:m.09dyl2g',
#  'fb:m.035fx7',
#  'fb:m.0h7lyxm',
#  'fb:m.0523c7l',
#  'fb:m.0hgx0fh',
#  'fb:m.02pxv5y',
#  'fb:m.026kcbp',
#  'fb:m.0_qtgql',
#  'fb:m.02_940',
#  'fb:m.05syzys',
#  'fb:m.0h7nmsv',
#  'fb:m.0gcg0sh',
#  'fb:m.0n9_967',
#  'fb:m.0bv764q',
#  'fb:m.0w_j3qc',
#  'fb:m.0bbxvj',
#  'fb:m.06xsps',
#  'fb:m.03cyfn6',
#  'fb:m.0h1xqy1',
#  'fb:m.036ftj',
#  'fb:m.03nfh2',
#  'fb:m.03c1twl',
#  'fb:m.0k7p6c',
#  'fb:m.0c0wrq',
#  'fb:m.0rylz7h',
#  'fb:m.014cg0',
#  'fb:m.02wbcb9',
#  'fb:m.02pnjxv',
#  'fb:m.0g4p35m',
#  'fb:m.0dxdkx',
#  'fb:m.03fzj1',
#  'fb:m.0cmc71f',
#  'fb:m.06t8gp',
#  'fb:m.07s9h6b',
#  'fb:m.0d4812',
#  'fb:m.0gkmf6',
#  'fb:m.027vhb2',
#  'fb:m.0hcd12m',
#  'fb:m.0wpw0qq',
#  'fb:m.0357pmz',
#  'fb:m.03xgln',
#  'fb:m.02x69fr',
#  'fb:m.05bhjn8',
#  'fb:m.0nh7d1h',
#  'fb:m.0yqdrb6',
#  'fb:m.0q56tz2',
#  'fb:m.0676v6',
#  'fb:m.03vgbf',
#  'fb:m.03c51vz',
#  'fb:m.026pc98',
#  'fb:m.0gpfk5',
#  'fb:m.0qgqxh_',
#  'fb:m.0bd07l1',
#  'fb:m.05zmgk1',
#  'fb:m.0261xcy',
#  'fb:m.0d_cvq',
#  'fb:m.06znnzy',
#  'fb:m.0q3ycpj',
#  'fb:m.04v16_',
#  'fb:m.02rdcby',
#  'fb:m.0pl4c7_',
#  'fb:m.01mjt7w',
#  'fb:m.0gwywf6',
#  ...}

# %%
# explore
lineid = 'valid-3981'
truth_mid, truth_rel, question = id2question[lineid]
print(id2question[lineid])
pred_relation = id2rel[lineid]
print(pred_relation)
query_text = id2query[lineid].lower()  # lowercase the query
print(query_text)
query_tokens = tokenize_text(query_text)
print(query_tokens)
N = min(len(query_tokens), 3)
print(N)
# Out:
# ('fb:m.04t4n1z', 'fb:book.written_work.subjects', "what's out of eden about")
# www.freebase.com/book/written_work/subjects
# eden
# ['eden']
# 1

# %%
C = []  # candidate entities
for n in range(N, 0, -1):
    ngrams_set = find_ngrams(query_tokens, n)
    print("ngrams_set: {}".format(ngrams_set))
    for ngram_tuple in ngrams_set:
        ngram = " ".join(ngram_tuple)
        ngram = strip_accents(ngram)
        # unigram stopwords have too many candidates so just skip over
        if ngram in stopwords:
            continue
        print("ngram: {}".format(ngram))
        ## PROBLEM! - ngram doesnt exist in index - at test-2592 - KeyError: 'p.a.r.c.e. parce'
        try:
            cand_mids = index_ent[ngram]  # search entities
        except:
            continue
        C.extend(cand_mids)
        # print("C: {}".format(C))
    if (len(C) > 0):
        print("early termination...")
        break
    break
print(C)
# Out:
# ngrams_set: {('eden',)}
# ngram: eden
# early termination...
# ['fb:m.0f7znh', 'fb:m.01hgtl3', 'fb:m.07kczh3', 'fb:m.0bqscbs', 'fb:m.04t_mjw', 'fb:m.02l3xr', 'fb:m.0dx7k6s', 'fb:m.0fdwv0h', 'fb:m.0ncd4yy', 'fb:m.0nv26gk', 'fb:m.0llkzs', 'fb:m.05b3gkt', 'fb:m.010jpp', 'fb:m.04v84j8', 'fb:m.04t4n1z', 'fb:m.098gdxt', 'fb:m.04dz23h', 'fb:m.062sr57', 'fb:m.0h12n2s', 'fb:m.01p73zv', 'fb:m.04t_pm3', 'fb:m.0njj6z_', 'fb:m.0kyxsnv', 'fb:m.011396', 'fb:m.0cc6w4r', 'fb:m.0gtl8ks', 'fb:m.0cs54k5', 'fb:m.02q533b', 'fb:m.027t41y', 'fb:m.0822mz', 'fb:m.027vl0z', 'fb:m.04d_5vp', 'fb:m.04_0nx_', 'fb:m.04t_mlf', 'fb:m.0jwz6gk', 'fb:m.04t_pkq', 'fb:m.02pmg8m', 'fb:m.0cnb7t8', 'fb:m.03cxtpd', 'fb:m.05t3kx', 'fb:m.01jdm6m', 'fb:m.032q6y', 'fb:m.07kwdy6', 'fb:m.04t_mkx', 'fb:m.04ttl6z', 'fb:m.02b7_m8', 'fb:m.04j1n_s', 'fb:m.071kwv', 'fb:m.0gfg67', 'fb:m.07hqkw', 'fb:m.04lfvv4', 'fb:m.04w61_4', 'fb:m.0488_s4', 'fb:m.01phfbw', 'fb:m.05sxgcb', 'fb:m.0j3zh16', 'fb:m.01ssjjb', 'fb:m.04jf9x', 'fb:m.0hmwj_p', 'fb:m.03jgxx1', 'fb:m.01lbwcw', 'fb:m.04993vd', 'fb:m.02n8v', 'fb:m.03fptzb', 'fb:m.04czczr', 'fb:m.04t_pmp', 'fb:m.0gps0z', 'fb:m.09vz98', 'fb:m.0f68p_', 'fb:m.0gf8kxz', 'fb:m.0488ldb', 'fb:m.03ckltt', 'fb:m.04v4j8r', 'fb:m.06_0s5h', 'fb:m.03vlz2', 'fb:m.0hzxln0', 'fb:m.0cc2zs0', 'fb:m.03hckyq', 'fb:m.01l7ffw', 'fb:m.04w71n4', 'fb:m.04xk9h', 'fb:m.0391pfh', 'fb:m.03nwzps', 'fb:m.0gyh6f_', 'fb:m.0gf8psw', 'fb:m.043kxtk', 'fb:m.063jh4', 'fb:m.02618k2', 'fb:m.0w0z7', 'fb:m.0478lp', 'fb:m.0wk4j', 'fb:m.04t_rz5', 'fb:m.0crs0ql', 'fb:m.04j0nmg', 'fb:m.01m6kmf', 'fb:m.048q48g', 'fb:m.0h8m_2_', 'fb:m.0421d3l', 'fb:m.04t_ry4', 'fb:m.04w517d', 'fb:m.04vgn2x', 'fb:m.0zk0f9l', 'fb:m.04j8n9', 'fb:m.07w9ht6', 'fb:m.06x2k_', 'fb:m.06fwxy', 'fb:m.03g3b6c', 'fb:m.04w3lz2', 'fb:m.0w2k0d_', 'fb:m.04gg79d', 'fb:m.05p4kz', 'fb:m.0gxcv96', 'fb:m.04t_ryx', 'fb:m.01s5j6x', 'fb:m.04909ym', 'fb:m.04283r', 'fb:m.0j_k3g', 'fb:m.01lrt2h', 'fb:m.03494_5', 'fb:m.0408kg', 'fb:m.03j86dh', 'fb:m.0crx1p4', 'fb:m.01sgfsc', 'fb:m.02w78cj', 'fb:m.0cs1xpt', 'fb:m.05yydmc', 'fb:m.04t4mjz', 'fb:m.0gksdry', 'fb:m.01qqmrq', 'fb:m.0h60vgc', 'fb:m.0c01csw', 'fb:m.0f8clr', 'fb:m.04m_hhf', 'fb:m.02qf92l', 'fb:m.0340rc', 'fb:m.026cktf', 'fb:m.0_qvc4g', 'fb:m.026rp1', 'fb:m.03hckpm', 'fb:m.04j34hv', 'fb:m.05f9xd6', 'fb:m.01qkt1', 'fb:m.05f8lk', 'fb:m.0gj4x8q', 'fb:m.0dr8_fd', 'fb:m.07cgs03', 'fb:m.04v8wlt', 'fb:m.09k5kf_', 'fb:m.0h3rgh9', 'fb:m.04cr6yq', 'fb:m.0b6g0fb', 'fb:m.0gsytzr', 'fb:m.0bbt_h2', 'fb:m.0dxngwd', 'fb:m.08nrbp', 'fb:m.04j2yf6', 'fb:m.02hl690', 'fb:m.02pm4jj', 'fb:m.04nlb9l', 'fb:m.0lw8vfc', 'fb:m.01rl7p4', 'fb:m.03z7_pk', 'fb:m.0q74vwz', 'fb:m.02q8xkp', 'fb:m.05p903', 'fb:m.0gr95c', 'fb:m.0320dys', 'fb:m.0c3zw62', 'fb:m.0zfkmj6', 'fb:m.04bvrk', 'fb:m.0564hky', 'fb:m.0dd3z5', 'fb:m.0r_8d', 'fb:m.063y2vd', 'fb:m.01kcmfw', 'fb:m.02_fp7', 'fb:m.0d7g89t', 'fb:m.026sg3c', 'fb:m.0dg2q6l', 'fb:m.04w8fc8', 'fb:m.058ncz', 'fb:m.0zcfdd1', 'fb:m.0b7dcbk', 'fb:m.048s7yf', 'fb:m.0brjxp', 'fb:m.06_wshw', 'fb:m.02hlq90', 'fb:m.0495gnn', 'fb:m.0k6gdxv', 'fb:m.06w53yy', 'fb:m.04t_pjw', 'fb:m.079j8y6', 'fb:m.04t_pl8', 'fb:m.03085_c', 'fb:m.04jkywn', 'fb:m.0dvzhr1', 'fb:m.031ygsg', 'fb:m.09xk3t5', 'fb:m.048prlz', 'fb:m.0drmc81', 'fb:m.04v456d', 'fb:m.041mg5', 'fb:m.064k7lm', 'fb:m.0b8x_x', 'fb:m.04whwvz', 'fb:m.04t4n2g', 'fb:m.0gc1x78', 'fb:m.03fptz5', 'fb:m.04t4fh2', 'fb:m.04wh3pn', 'fb:m.04t_pn7', 'fb:m.03xw6h6', 'fb:m.015d6d', 'fb:m.028911j', 'fb:m.05sqd7h', 'fb:m.04t_mkb', 'fb:m.048p1sk', 'fb:m.03hjjy0', 'fb:m.0vp0zhr', 'fb:m.0fqtvf4', 'fb:m.05c2yj8', 'fb:m.044my5', 'fb:m.01wm357', 'fb:m.02qdg06', 'fb:m.0tjv7qq', 'fb:m.02w9r2_', 'fb:m.0c85f1', 'fb:m.04w52pd', 'fb:m.0ws4m', 'fb:m.02bf8pj', 'fb:m.03flgqw', 'fb:m.04t_mnx', 'fb:m.0dshvnt', 'fb:m.05f_b2', 'fb:m.02qq2sw', 'fb:m.029rst', 'fb:m.0gks1yp', 'fb:m.01ldbk2', 'fb:m.026x14j', 'fb:m.02vx347', 'fb:m.052lgq', 'fb:m.04wfhm3', 'fb:m.04t_pk4', 'fb:m.05t0mrr', 'fb:m.0dkd7k9', 'fb:m.04trgtx', 'fb:m.03cny7m', 'fb:m.01j3xxc', 'fb:m.0_sknz3', 'fb:m.0wyg6ld', 'fb:m.04t_pkf', 'fb:m.0wd6m', 'fb:m.01md2hg', 'fb:m.04vg ...

# %%
print(index_names['fb:m.0504s2'])
# Out:
# ['scotty', 'gomer', 'scott gomez', 'scott carlos gomez']

# %%
C_pruned = []
for mid in set(C):
    if mid in index_reach.keys():  # PROBLEM: don't know why this may not exist??
        count_mid = C.count(mid)  # count number of times mid appeared in C
        C_pruned.append((mid, count_mid))
#         if pred_relation in index_reach[mid]:
#             count_mid = C.count(mid)  # count number of times mid appeared in C
#             C_pruned.append((mid, count_mid))

print(C_pruned)
# Out:
# [('fb:m.0f7znh', 1), ('fb:m.01hgtl3', 1), ('fb:m.07kczh3', 1), ('fb:m.0bqscbs', 1), ('fb:m.04t_mjw', 1), ('fb:m.02l3xr', 1), ('fb:m.0dx7k6s', 1), ('fb:m.0fdwv0h', 1), ('fb:m.0ncd4yy', 1), ('fb:m.0nv26gk', 1), ('fb:m.0llkzs', 1), ('fb:m.05b3gkt', 1), ('fb:m.010jpp', 1), ('fb:m.04v84j8', 1), ('fb:m.04t4n1z', 1), ('fb:m.098gdxt', 1), ('fb:m.04dz23h', 1), ('fb:m.062sr57', 1), ('fb:m.0h12n2s', 1), ('fb:m.01p73zv', 1), ('fb:m.04t_pm3', 1), ('fb:m.0njj6z_', 1), ('fb:m.0kyxsnv', 1), ('fb:m.011396', 1), ('fb:m.0cc6w4r', 1), ('fb:m.0gtl8ks', 1), ('fb:m.0cs54k5', 1), ('fb:m.02q533b', 1), ('fb:m.027t41y', 1), ('fb:m.0822mz', 1), ('fb:m.027vl0z', 1), ('fb:m.04d_5vp', 1), ('fb:m.04_0nx_', 1), ('fb:m.04t_mlf', 1), ('fb:m.0jwz6gk', 1), ('fb:m.04t_pkq', 1), ('fb:m.02pmg8m', 1), ('fb:m.0cnb7t8', 1), ('fb:m.03cxtpd', 1), ('fb:m.05t3kx', 1), ('fb:m.01jdm6m', 1), ('fb:m.032q6y', 1), ('fb:m.07kwdy6', 1), ('fb:m.04t_mkx', 1), ('fb:m.04ttl6z', 1), ('fb:m.02b7_m8', 1), ('fb:m.04j1n_s', 1), ('fb:m.071kwv', 1), ('fb:m.0gfg67', 1), ('fb:m.07hqkw', 1), ('fb:m.04lfvv4', 1), ('fb:m.04w61_4', 1), ('fb:m.0488_s4', 1), ('fb:m.01phfbw', 1), ('fb:m.05sxgcb', 1), ('fb:m.0j3zh16', 1), ('fb:m.01ssjjb', 1), ('fb:m.04jf9x', 1), ('fb:m.0hmwj_p', 1), ('fb:m.03jgxx1', 1), ('fb:m.01lbwcw', 1), ('fb:m.04993vd', 1), ('fb:m.02n8v', 1), ('fb:m.03fptzb', 1), ('fb:m.04czczr', 1), ('fb:m.04t_pmp', 1), ('fb:m.0gps0z', 1), ('fb:m.09vz98', 1), ('fb:m.0f68p_', 1), ('fb:m.0gf8kxz', 1), ('fb:m.0488ldb', 1), ('fb:m.03ckltt', 1), ('fb:m.04v4j8r', 1), ('fb:m.06_0s5h', 1), ('fb:m.03vlz2', 1), ('fb:m.0hzxln0', 1), ('fb:m.0cc2zs0', 1), ('fb:m.03hckyq', 1), ('fb:m.01l7ffw', 1), ('fb:m.04w71n4', 1), ('fb:m.04xk9h', 1), ('fb:m.0391pfh', 1), ('fb:m.03nwzps', 1), ('fb:m.0gyh6f_', 1), ('fb:m.0gf8psw', 1), ('fb:m.043kxtk', 1), ('fb:m.063jh4', 1), ('fb:m.02618k2', 1), ('fb:m.0w0z7', 1), ('fb:m.0478lp', 1), ('fb:m.0wk4j', 1), ('fb:m.04t_rz5', 1), ('fb:m.0crs0ql', 1), ('fb:m.04j0nmg', 1), ('fb:m.01m6kmf', 1), ('fb:m.048q48g', 1), ('fb:m.0h8m_2_', 1), ('fb:m.04t_ry4', 1), ('fb:m.0421d3l', 1), ('fb:m.04w517d', 1), ('fb:m.04vgn2x', 1), ('fb:m.0zk0f9l', 1), ('fb:m.04j8n9', 1), ('fb:m.07w9ht6', 1), ('fb:m.06x2k_', 1), ('fb:m.06fwxy', 1), ('fb:m.03g3b6c', 1), ('fb:m.04w3lz2', 1), ('fb:m.0w2k0d_', 1), ('fb:m.04gg79d', 1), ('fb:m.05p4kz', 1), ('fb:m.0gxcv96', 1), ('fb:m.04t_ryx', 1), ('fb:m.01s5j6x', 1), ('fb:m.04909ym', 1), ('fb:m.04283r', 1), ('fb:m.0j_k3g', 1), ('fb:m.01lrt2h', 1), ('fb:m.03494_5', 1), ('fb:m.0408kg', 1), ('fb:m.03j86dh', 1), ('fb:m.0crx1p4', 1), ('fb:m.01sgfsc', 1), ('fb:m.02w78cj', 1), ('fb:m.0cs1xpt', 1), ('fb:m.05yydmc', 1), ('fb:m.04t4mjz', 1), ('fb:m.0gksdry', 1), ('fb:m.01qqmrq', 1), ('fb:m.0h60vgc', 1), ('fb:m.0c01csw', 1), ('fb:m.0f8clr', 1), ('fb:m.04m_hhf', 1), ('fb:m.02qf92l', 1), ('fb:m.0340rc', 1), ('fb:m.026cktf', 1), ('fb:m.0_qvc4g', 1), ('fb:m.026rp1', 1), ('fb:m.03hckpm', 1), ('fb:m.04j34hv', 1), ('fb:m.05f9xd6', 1), ('fb:m.01qkt1', 1), ('fb:m.05f8lk', 1), ('fb:m.0gj4x8q', 1), ('fb:m.0dr8_fd', 1), ('fb:m.07cgs03', 1), ('fb:m.04v8wlt', 1), ('fb:m.09k5kf_', 1), ('fb:m.0h3rgh9', 1), ('fb:m.04cr6yq', 1), ('fb:m.0b6g0fb', 1), ('fb:m.0gsytzr', 1), ('fb:m.0bbt_h2', 1), ('fb:m.0dxngwd', 1), ('fb:m.08nrbp', 1), ('fb:m.04j2yf6', 1), ('fb:m.02hl690', 1), ('fb:m.02pm4jj', 1), ('fb:m.04nlb9l', 1), ('fb:m.0lw8vfc', 1), ('fb:m.01rl7p4', 1), ('fb:m.03z7_pk', 1), ('fb:m.0q74vwz', 1), ('fb:m.02q8xkp', 1), ('fb:m.05p903', 1), ('fb:m.0gr95c', 1), ('fb:m.0320dys', 1), ('fb:m.0c3zw62', 1), ('fb:m.0zfkmj6', 1), ('fb:m.04bvrk', 1), ('fb:m.0564hky', 1), ('fb:m.0dd3z5', 1), ('fb:m.0r_8d', 1), ('fb:m.063y2vd', 1), ('fb:m.01kcmfw', 1), ('fb:m.02_fp7', 1), ('fb:m.0d7g89t', 1), ('fb:m.026sg3c', 1), ('fb:m.0dg2q6l', 1), ('fb:m.04w8fc8', 1), ('fb:m.058ncz', 1), ('fb:m.0zcfdd1', 1), ('fb:m.0b7dcbk', 1), ('fb:m.048s7yf', 1), ('fb:m.0brjxp', 1), ('fb:m.06_wshw', 1), ('fb:m.02hlq90', 1), ('fb:m.0495gnn', 1), ('fb:m.0k6gdxv', 1), ('fb:m.06w53yy', 1), ('fb:m.04t_pjw', 1), ('fb:m.079j8y6', 1), ('fb:m.04t_pl8 ...

# %%
C_tfidf_pruned = []
for mid, count_mid in C_pruned:
    if mid in index_names.keys():
        cand_ent_name = pick_best_name(question, index_names[mid])
        score = fuzzy_match(cand_ent_name, question)
#         score = calc_tf_idf(query_text, cand_ent_name, count_mid, num_entities_fbsubset, index_ent)
        C_tfidf_pruned.append((mid, score))
# print("C_tfidf_pruned[:10]: {}".format(C_tfidf_pruned[:10]))
print(C_tfidf_pruned)
# Out:
# [('fb:m.0f7znh', 67), ('fb:m.01hgtl3', 100), ('fb:m.07kczh3', 64), ('fb:m.0bqscbs', 53), ('fb:m.04t_mjw', 55), ('fb:m.02l3xr', 71), ('fb:m.0dx7k6s', 100), ('fb:m.0fdwv0h', 100), ('fb:m.0ncd4yy', 47), ('fb:m.0nv26gk', 57), ('fb:m.0llkzs', 69), ('fb:m.05b3gkt', 43), ('fb:m.010jpp', 50), ('fb:m.04v84j8', 54), ('fb:m.04t4n1z', 100), ('fb:m.098gdxt', 48), ('fb:m.04dz23h', 38), ('fb:m.062sr57', 42), ('fb:m.0h12n2s', 50), ('fb:m.01p73zv', 53), ('fb:m.04t_pm3', 55), ('fb:m.0njj6z_', 55), ('fb:m.0kyxsnv', 67), ('fb:m.011396', 54), ('fb:m.0cc6w4r', 62), ('fb:m.0gtl8ks', 43), ('fb:m.0cs54k5', 46), ('fb:m.02q533b', 100), ('fb:m.027t41y', 69), ('fb:m.0822mz', 44), ('fb:m.027vl0z', 44), ('fb:m.04d_5vp', 50), ('fb:m.04_0nx_', 53), ('fb:m.04t_mlf', 55), ('fb:m.0jwz6gk', 42), ('fb:m.04t_pkq', 55), ('fb:m.02pmg8m', 42), ('fb:m.0cnb7t8', 42), ('fb:m.03cxtpd', 50), ('fb:m.05t3kx', 57), ('fb:m.01jdm6m', 50), ('fb:m.032q6y', 56), ('fb:m.07kwdy6', 42), ('fb:m.04t_mkx', 55), ('fb:m.04ttl6z', 75), ('fb:m.02b7_m8', 42), ('fb:m.04j1n_s', 56), ('fb:m.071kwv', 58), ('fb:m.0gfg67', 38), ('fb:m.07hqkw', 55), ('fb:m.04lfvv4', 57), ('fb:m.04w61_4', 58), ('fb:m.0488_s4', 55), ('fb:m.01phfbw', 70), ('fb:m.05sxgcb', 45), ('fb:m.0j3zh16', 55), ('fb:m.01ssjjb', 57), ('fb:m.04jf9x', 55), ('fb:m.0hmwj_p', 50), ('fb:m.03jgxx1', 62), ('fb:m.01lbwcw', 100), ('fb:m.04993vd', 67), ('fb:m.02n8v', 58), ('fb:m.03fptzb', 100), ('fb:m.04czczr', 67), ('fb:m.04t_pmp', 55), ('fb:m.0gps0z', 41), ('fb:m.09vz98', 46), ('fb:m.0f68p_', 39), ('fb:m.0gf8kxz', 56), ('fb:m.0488ldb', 56), ('fb:m.03ckltt', 42), ('fb:m.04v4j8r', 50), ('fb:m.06_0s5h', 75), ('fb:m.03vlz2', 57), ('fb:m.0hzxln0', 57), ('fb:m.0cc2zs0', 50), ('fb:m.03hckyq', 42), ('fb:m.01l7ffw', 52), ('fb:m.04w71n4', 62), ('fb:m.04xk9h', 30), ('fb:m.0391pfh', 55), ('fb:m.03nwzps', 43), ('fb:m.0gyh6f_', 52), ('fb:m.0gf8psw', 58), ('fb:m.043kxtk', 50), ('fb:m.063jh4', 60), ('fb:m.02618k2', 54), ('fb:m.0w0z7', 50), ('fb:m.0478lp', 50), ('fb:m.0wk4j', 39), ('fb:m.04t_rz5', 42), ('fb:m.0crs0ql', 42), ('fb:m.04j0nmg', 58), ('fb:m.01m6kmf', 64), ('fb:m.048q48g', 47), ('fb:m.0h8m_2_', 50), ('fb:m.04t_ry4', 55), ('fb:m.0421d3l', 47), ('fb:m.04w517d', 55), ('fb:m.04vgn2x', 53), ('fb:m.0zk0f9l', 50), ('fb:m.04j8n9', 29), ('fb:m.07w9ht6', 67), ('fb:m.06x2k_', 42), ('fb:m.06fwxy', 64), ('fb:m.03g3b6c', 42), ('fb:m.04w3lz2', 42), ('fb:m.0w2k0d_', 35), ('fb:m.04gg79d', 68), ('fb:m.05p4kz', 67), ('fb:m.0gxcv96', 46), ('fb:m.04t_ryx', 42), ('fb:m.01s5j6x', 56), ('fb:m.04909ym', 57), ('fb:m.04283r', 75), ('fb:m.0j_k3g', 46), ('fb:m.01lrt2h', 75), ('fb:m.03494_5', 100), ('fb:m.0408kg', 70), ('fb:m.03j86dh', 54), ('fb:m.0crx1p4', 46), ('fb:m.01sgfsc', 45), ('fb:m.02w78cj', 58), ('fb:m.0cs1xpt', 50), ('fb:m.05yydmc', 46), ('fb:m.04t4mjz', 59), ('fb:m.0gksdry', 100), ('fb:m.01qqmrq', 55), ('fb:m.0h60vgc', 53), ('fb:m.0c01csw', 40), ('fb:m.0f8clr', 30), ('fb:m.04m_hhf', 50), ('fb:m.02qf92l', 61), ('fb:m.0340rc', 38), ('fb:m.026cktf', 60), ('fb:m.0_qvc4g', 46), ('fb:m.026rp1', 55), ('fb:m.03hckpm', 42), ('fb:m.04j34hv', 100), ('fb:m.05f9xd6', 75), ('fb:m.01qkt1', 75), ('fb:m.05f8lk', 38), ('fb:m.0gj4x8q', 64), ('fb:m.0dr8_fd', 42), ('fb:m.07cgs03', 75), ('fb:m.04v8wlt', 75), ('fb:m.09k5kf_', 75), ('fb:m.0h3rgh9', 67), ('fb:m.04cr6yq', 71), ('fb:m.0b6g0fb', 60), ('fb:m.0gsytzr', 50), ('fb:m.0bbt_h2', 50), ('fb:m.0dxngwd', 71), ('fb:m.08nrbp', 30), ('fb:m.04j2yf6', 56), ('fb:m.02hl690', 58), ('fb:m.02pm4jj', 33), ('fb:m.04nlb9l', 100), ('fb:m.0lw8vfc', 57), ('fb:m.01rl7p4', 56), ('fb:m.03z7_pk', 67), ('fb:m.0q74vwz', 57), ('fb:m.02q8xkp', 50), ('fb:m.05p903', 70), ('fb:m.0gr95c', 56), ('fb:m.0320dys', 65), ('fb:m.0c3zw62', 50), ('fb:m.0zfkmj6', 50), ('fb:m.04bvrk', 54), ('fb:m.0564hky', 56), ('fb:m.0dd3z5', 50), ('fb:m.0r_8d', 58), ('fb:m.063y2vd', 67), ('fb:m.01kcmfw', 46), ('fb:m.02_fp7', 64), ('fb:m.0d7g89t', 56), ('fb:m.026sg3c', 45), ('fb:m.0dg2q6l', 54), ('fb:m.04w8fc8', 53), ('fb:m.058ncz', 42), ('fb:m.0zcfdd1', 70), ('fb:m.0b7dcbk', 67), ('fb:m.0 ...

# %%
notfound_ent = 0
notfound_c = 0
notfound_c_lineids = []
notfound_ent = 0
notcorrect_ent_lineids = []
id2pred_ent = {}

for i, lineid in enumerate(rel_lineids):
    if lineid not in ent_lineids:
        notfound_ent += 1
        continue

    pred_relation = www2fb(id2rel[lineid])
    query_text = id2query[lineid].lower()  # lowercase the query
    query_tokens = tokenize_text(query_text)

    # print("lineid: {}, query_text: {}, relation: {}".format(lineid, query_text, pred_relation))
    # print("query_tokens: {}".format(query_tokens))

    N = min(len(query_tokens), 3)
    C = []  # candidate entities
    for n in range(N, 0, -1):
        ngrams_set = find_ngrams(query_tokens, n)
        # print("ngrams_set: {}".format(ngrams_set))
        for ngram_tuple in ngrams_set:
            ngram = " ".join(ngram_tuple)
            ngram = strip_accents(ngram)
            # unigram stopwords have too many candidates so just skip over
            if ngram in stopwords:
                continue
            # print("ngram: {}".format(ngram))
            ## PROBLEM! - ngram doesnt exist in index - at test-2592 - KeyError: 'p.a.r.c.e. parce'
            try:
                cand_mids = index_ent[ngram]  # search entities
            except:
                continue
            C.extend(cand_mids)
            # print("C: {}".format(C))
        if (len(C) > 0):
            # print("early termination...")
            break
    # print("C[:5]: {}".format(C[:5]))

    # relation correction
    C_pruned = []
    for mid in set(C):
        if mid in index_reach.keys():  # PROBLEM: don't know why this may not exist??
            count_mid = C.count(mid)  # count number of times mid appeared in C
            C_pruned.append((mid, count_mid))
            ### NOT DOING RELATION CORRECTION HERE!!
#             if pred_relation in index_reach[mid]:
#                 count_mid = C.count(mid)  # count number of times mid appeared in C
#                 C_pruned.append((mid, count_mid))
    # print("C_pruned[:5]: {}".format(C_pruned[:5]))

    C_tfidf_pruned = []
    for mid, count_mid in C_pruned:
        if mid in index_names.keys():
            cand_ent_name = pick_best_name(question, index_names[mid])
            tfidf = calc_tf_idf(query_text, cand_ent_name, count_mid, num_entities_fbsubset, index_ent)
            C_tfidf_pruned.append((mid, tfidf))
    # print("C_tfidf_pruned[:10]: {}".format(C_tfidf_pruned[:10]))

    if len(C_tfidf_pruned) == 0:
        #print("WARNING: C_tfidf_pruned is empty.")
        notfound_c_lineids.append(lineid)
        notfound_c += 1
        continue

    C_tfidf_pruned.sort(key=lambda t: -t[1])
    pred_ent_mid = C_tfidf_pruned[0][0]  # get first entry's mid

    line_to_print = "{}\t{}\t{}".format(lineid, pred_ent_mid, pred_relation)
    id2pred_ent[lineid] = pred_ent_mid
    #print("PRED: " + line_to_print)
    
    gold_ent_mid, gold_rel, question = id2question[lineid]
    if not gold_ent_mid == pred_ent_mid:
        notfound_ent += 1
        notcorrect_ent_lineids.append(lineid)
        
    if (i+1) % 100 == 0:
        print("at line {}".format(i+1))
    if (i+1) % 1000 == 0:
        break
    # outfile.write(line_to_print + "\n")

print("notfound_ent : {}".format(notfound_ent))
print("notfound_c : {}".format(notfound_c))
print("notfound_c_lineids: {}".format(notfound_c_lineids))
print("notcorrect_ent_lineids: {}".format(notcorrect_ent_lineids))
#outfile.close()
# Out:
# at line 100
# at line 200
# at line 300
# at line 400
# at line 500
# at line 600
# at line 700
# at line 800
# at line 900
# at line 1000
# notfound_ent : 483
# notfound_c : 7
# notfound_c_lineids: ['test-40', 'test-146', 'test-312', 'test-414', 'test-578', 'test-742', 'test-848']
# notcorrect_ent_lineids: ['test-2', 'test-6', 'test-7', 'test-8', 'test-11', 'test-12', 'test-15', 'test-18', 'test-19', 'test-20', 'test-22', 'test-23', 'test-24', 'test-25', 'test-26', 'test-27', 'test-29', 'test-30', 'test-31', 'test-32', 'test-39', 'test-41', 'test-43', 'test-45', 'test-47', 'test-48', 'test-49', 'test-50', 'test-52', 'test-61', 'test-65', 'test-66', 'test-67', 'test-68', 'test-69', 'test-71', 'test-73', 'test-75', 'test-76', 'test-77', 'test-78', 'test-79', 'test-81', 'test-82', 'test-85', 'test-87', 'test-88', 'test-91', 'test-92', 'test-93', 'test-94', 'test-95', 'test-96', 'test-97', 'test-98', 'test-100', 'test-104', 'test-105', 'test-110', 'test-112', 'test-113', 'test-118', 'test-125', 'test-127', 'test-128', 'test-129', 'test-130', 'test-132', 'test-133', 'test-134', 'test-135', 'test-137', 'test-138', 'test-145', 'test-149', 'test-153', 'test-156', 'test-157', 'test-158', 'test-159', 'test-160', 'test-162', 'test-163', 'test-166', 'test-168', 'test-171', 'test-181', 'test-183', 'test-187', 'test-188', 'test-189', 'test-191', 'test-194', 'test-196', 'test-200', 'test-202', 'test-205', 'test-207', 'test-211', 'test-212', 'test-213', 'test-214', 'test-215', 'test-219', 'test-220', 'test-221', 'test-222', 'test-223', 'test-227', 'test-229', 'test-230', 'test-231', 'test-234', 'test-238', 'test-239', 'test-245', 'test-247', 'test-249', 'test-250', 'test-252', 'test-254', 'test-256', 'test-262', 'test-263', 'test-264', 'test-265', 'test-267', 'test-269', 'test-270', 'test-271', 'test-273', 'test-275', 'test-276', 'test-278', 'test-280', 'test-283', 'test-286', 'test-288', 'test-293', 'test-295', 'test-297', 'test-298', 'test-299', 'test-301', 'test-303', 'test-305', 'test-306', 'test-307', 'test-309', 'test-311', 'test-317', 'test-318', 'test-328', 'test-329', 'test-331', 'test-334', 'test-335', 'test-336', 'test-338', 'test-339', 'test-342', 'test-344', 'test-346', 'test-347', 'test-350', 'test-353', 'test-354', 'test-355', 'test-357', 'test-360', 'test-361', 'test-362', 'test-363', 'test-364', 'test-366', 'test-371', 'test-373', 'test-375', 'test-376', 'test-377', 'test-378', 'test-379', 'test-381', 'test-384', 'test-385', 'test-386', 'test-389', 'test-390', 'test-391', 'test-395', 'test-396', 'test-397', 'test-398', 'test-401', 'test-404', 'test-405', 'test-406', 'test-420', 'test-422', 'test-423', 'test-424', 'test-425', 'test-426', 'test-429', 'test-432', 'test-433', 'test-434', 'test-437', 'test-439', 'test-441', 'test-449', 'test-450', 'test-452', 'test-455', 'test-456', 'test-457', 'test-459', 'test-461', 'test-463', 'test-465', 'test-466', 'test-468', 'test-475', 'test-476', 'test-477', 'test-479', 'test-485', 'test-488', 'test-493', 'test-494', 'test-496', 'test-497', 'test-498', 'test-499', 'test-500', 'test-501', 'test-504', 'test-506', 'test-509', 'test-510', 'test-511', 'test-512', 'test-515', 'test-517', 'test-520', 'test-523', 'test-530', 'test-531', 'test-532', 'test-534', 'test-535', 'test-541', 'test-542', 'test-543', 'test-545', 'test-547', 'test-549', 'test-550', 'test-551', 'test-553', 'test-554', 'test-555', 'test-557', 'test-561', 'test-563', 'test-565', 'test-568', 'test-569', 'test-571', 'test-572', 'test-575', 'test-577', 'test-580', 'test-581', 'test-582', 'test-583', 'test-584', 'test-585', 'test-589', 'test-590', 'test-592', 'test-593', 'test-600', 'test-601', 'test-602', 'test-603', 'test-604', 'test-608', 'test-610', 'test-611', 'test-612', 'test-613', 'test-614', 'test-617', 'test-618', 'test-622', 'test-623', 'test-626', 'test-629', 'test-630', 'test-635', 'test-636', 'test-638', 'test-639', 'test-640', 'test-643', 'test-644', 'test-646', 'test-649', 'test-650', 'test-651', 'test-654', 'test-662', 'test-663', 'test-667', 'test-671', 'test-672', 'test-676', 'test-677', 'test-678', 'test-680', 'test-681', 'test-682', 'test-683', 'test-685', 'test-686', 'test-690', 'test-691', 'test-695', 'test-699', 'test-700', 'test-702', 'test-703', 'test-705', 'test-706', 'test-707', 't ...

# %%
notfound_c_lineids = ['test-40', 'test-146', 'test-312', 'test-414', 'test-578', 'test-742', 'test-848']
df = []
pred_rel_fault = 0
names_fault = 0
other_fault = 0
names = ['question', 'gold_entity_id', 'gold_entity_name', 'gold_relation', 'query_text', 'predicted_relation']
for lineid in notfound_c_lineids[:50]:
    ent, rel, question = id2question[lineid]
    pred_relation = www2fb(id2rel[lineid])
    query_text = id2query[lineid].lower()  # lowercase the query
#     pred_ent_mid = id2pred_ent[lineid]
    if not pred_relation == rel:
        pred_rel_fault += 1
    else:
        other_fault += 1
    if ent in index_names.keys():
        row = [question, ent, pick_best_name(question, index_names[ent]), rel, query_text, pred_relation]
    else:
        names_fault += 1
    df.append(row)

df = pd.DataFrame(df)
df.columns = names

print(pred_rel_fault)
print(names_fault)
print(other_fault)
# Out:
# 3
# 0
# 4

# %%
df
# Out:
#                                             question gold_entity_id  \
# 0        Which label is somevelvetsidewalk signed to   fb:m.01pm4nb
# 1        what is a short-lived British sitcom series     fb:m.0c4xc
# 2  Who is the focus of uttar pradesh has more tha...   fb:m.0j2hj_0
# 3                    what genre of music is locd out   fb:m.01rrs9n
# 4                     what is cassiesteele's gender?    fb:m.03_fby
# 5                  what is the genre of gusgofficial   fb:m.03f3bp7
# 6  What is the title of the netlix film in the ge...     fb:m.03_3d
#
#                            gold_entity_name  \
# 0                      some velvet sidewalk
# 1                          situation comedy
# 2  uttar pradesh has more than one capital.
# 3                                loc 'd out
# 4                             cassie steele
# 5                      kostas karamitroudis
# 6                    land of the rising sun
#
#                           gold_relation          query_text  \
# 0                 fb:music.artist.label  somevelvetsidewalk
# 1               fb:tv.tv_genre.programs         short-lived
# 2      fb:base.uncommon.exception.focus                than
# 3                  fb:music.album.genre            locd out
# 4               fb:people.person.gender        cassiesteele
# 5                 fb:music.artist.genre        gusgofficial
# 6  fb:media_common.netflix_genre.titles              netlix
#
#                             predicted_relation
# 0                        fb:music.artist.label
# 1                      fb:tv.tv_genre.programs
# 2  fb:base.culturalevent.event.entity_involved
# 3                         fb:music.album.genre
# 4                      fb:people.person.gender
# 5                         fb:music.album.genre
# 6       fb:film.film_genre.films_in_this_genre

# %%
notcorrect_ent_lineids = ['test-2', 'test-6', 'test-7', 'test-8', 'test-11', 'test-12', 'test-15', 'test-18', 'test-19', 'test-20', 'test-22', 'test-23', 'test-24', 'test-25', 'test-26', 'test-27', 'test-29', 'test-30', 'test-31', 'test-32', 'test-39', 'test-41', 'test-43', 'test-45', 'test-47', 'test-48', 'test-49', 'test-50', 'test-52', 'test-61', 'test-65', 'test-66', 'test-67', 'test-68', 'test-69', 'test-71', 'test-73', 'test-75', 'test-76', 'test-77', 'test-78', 'test-79', 'test-81', 'test-82', 'test-85', 'test-87', 'test-88', 'test-91', 'test-92', 'test-93', 'test-94', 'test-95', 'test-96', 'test-97', 'test-98', 'test-100', 'test-104', 'test-105', 'test-110', 'test-112', 'test-113', 'test-118', 'test-125', 'test-127', 'test-128']

df = []
pred_rel_fault = 0
names_fault = 0
other_fault = 0
names = ['question', 'gold_ent_name', 'query_text', 'predicted_ent_name']
for lineid in notcorrect_ent_lineids[:50]:
    ent, rel, question = id2question[lineid]
    pred_relation = www2fb(id2rel[lineid])
    query_text = id2query[lineid].lower()  # lowercase the query
    pred_ent_mid = id2pred_ent[lineid]
    if not pred_relation == rel:
        pred_rel_fault += 1
    else:
        other_fault += 1
    if ent in index_names.keys():
        row = [question, pick_best_name(question,index_names[ent]), query_text,  pick_best_name(question,index_names[pred_ent_mid])]
    else:
        names_fault += 1
    df.append(row)

df = pd.DataFrame(df)
df.columns = names

print(pred_rel_fault)
print(names_fault)
print(other_fault)
# Out:
# 13
# 1
# 37

# %%
df
# Out:
#                                              question  \
# 0                             what format is fearless
# 1           what was the cause of death of yves klein
# 2                Which equestrian was born in dublin?
# 3                           What is a tv action show?
# 4                          What's a song by jean grae
# 5               What position does carlos gomez play?
# 6                  What's a release on pretty in pink
# 7                   Who created the typeface chicago?
# 8   what position does pee wee reese play in baseball
# 9              which artist recorded one life to live
# 10                       what is a track on carpenter
# 11  Which Swiss conductor's cause of death is myoc...
# 12          what type of music does david ruffin play
# 13     what tracks are listed in the release equator?
# 14   What is the track los angeles is a recording of?
# 15                                Name a history film
# 16                          what language is viper in
# 17  what's the name of an environmental disaster i...
# 18           Where was magical mystery tour released?
# 19                   Who influenced michael mcdowell?
# 20         what is the content type of voodoo lounge?
# 21                         which group recorded tokyo
# 22                         who is the creator of loud
# 23        What is the name of a western (genre) film?
# 24                    Who was born in aguascalientes?
# 25                   What is an album by herb alpert?
# 26                   what is angie estes's profession
# 27             what song was on the recording indiana
# 28     what position does josé francisco torres play?
# 29                where was held for british columbia
# 30    which event took place in italia (roman empire)
# 31              Who did the music for the film taffin
# 32                what male actor was born in  warsaw
# 33  What's an album that the philharmonia orchestr...
# 34     what kind of school is holy cross high school?
# 35                What kind of release was collection
# 36                   What would be a indie rock album
# 37                       How was phrenology released?
# 38                       How was phrenology released?
# 39                       who was also born in jakarta
# 40                 Where is buckingham palace located
# 41                             Who was born in prague
# 42  what country released  she gets out the scrapbook
# 43    What is a recording off the release to the sea?
# 44                 what type of album is  cherry 2000
# 45          Which country is archibald campbell from?
# 46     who is a fictional character that is a gambler
# 47             What is a book written about election?
# 48          what character is of the vampire species?
# 49  What is the name of a game in the gambling ind...
#
#                        gold_ent_name                  query_text  \
# 0                           fearless                    fearless
# 1                         yves klein                  yves klein
# 2       dublin , republic of ireland                      dublin
# 3                             action                 action show
# 4                          jean grae                   jean grae
# 5          carlos argelis gomez pena                carlos gomez
# 6                     pretty in pink              pretty in pink
# 7                            chicago            typeface chicago
# 8                      pee wee reese               pee wee reese
# 9                   one life to live            one life to live
# 10                         carpenter                   carpenter
# 11       acute myocardial infarction       myocardial infarction
# 12                      david ruffin                david ruffin
# 13                           equator                     equator
# 14                       los angeles                 los angeles
# 15                           history                     history
# 16                             viper                       viper
# 17            environmental disaster               environmental
# 18              magical mystery tour        magical mystery tour
# 19                  michael mcdowell            michael mcdowell
# 20                     voodoo lounge               voodoo lounge
# 21                             tokyo                       tokyo
# 22                              loud                        loud
# 23                     western movie                     western
# 24          estado de aguascalientes              aguascalientes
# 25         herbert `` herb '' alpert                 herb alpert
# 26                       angie estes                       angie
# 27                           indiana                     indiana
# 28             jose francisco torres              josé francisco
# 29      province of british columbia            british columbia
# 30                       roman italy         italia roman empire
# 31                            taffin                      taffin
# 32                   miasto warszawa                      warsaw
# 33  new philharmonia orchestra , the      philharmonia orchestra
# 34            holy cross high school      holy cross high school
# 35                        collection                  collection
# 36                        indie rock                  indie rock
# 37                        phrenology                  phrenology
# 38                        phrenology                  phrenology
# 39     daerah khusus ibokota jakarta                     jakarta
# 40        buckingham palace , london           buckingham palace
# 41                            prague                      prague
# 42        she gets out the scrapbook  she gets out the scrapbook
# 43                        to the sea                  to the sea
# 44                       cherry 2000                 cherry 2000
# 45                archibald campbell          archibald campbell
# 46                 steven sharpe iii                     gambler
# 47                          election                    election
# 48                          vampires                     vampire
# 49                          gambling                    gambling
#
#                                    predicted_ent_name
# 0                                            fearless
# 1                                     yves klein blue
# 2                                              dublin
# 3                                     junit in action
# 4             grae fruits : the jean grae compilation
# 5                                  scott carlos gomez
# 6                                      pretty in pink
# 7                                            typeface
# 8   pee wee & jackie : pee wee reese & jackie robi...
# 9                 lady in the dark : one life to live
# 10                                          carpenter
# 11                              myocardial infarction
# 12  20th century masters : the millennium collecti...
# 13                                       equator farm
# 14                                        los angeles
# 15                                            history
# 16                                   day of the viper
# 17                            environmental chemistry
# 18                               magical mystery tour
# 19                                   michael mcdowell
# 20                                      voodoo lounge
# 21                         1995-10-28 : tokyo , japan
# 22                                  thinking out loud
# 23                                       epic western
# 24                          asientos , aguascalientes
# 25                          the essential herb alpert
# 26                                         angie bray
# 27                                   abydel , indiana
# 28                            jose francisco lafuente
# 29                     fort nelson , british columbia
# 30                           pigs of the roman empire
# 31                                    amandine taffin
# 32                                             warsaw
# 33  tristan und isolde ( chorus of the royal opera...
# 34                             holy cross high school
# 35                          the definitive collection
# 36  red hot + bothered : the indie rock guide to d...
# 37                                         phrenology
# 38                                         phrenology
# 39                                   jakarta monorail
# 40                                  buckingham palace
# 41  smetana : ma vlast / the bartered bride / hako...
# 42                         she gets out the scrapbook
# 43                                  riders to the sea
# 44                     cherry 2000 / the house of god
# 45                                 archibald campbell
# 46                                        the gambler
# 47         united states presidential election , 1924
# 48                           buffy the vampire slayer
# 49                   gambling theory and other topics

# %%
df.to_csv('incorrect_ents_without_rel_correction.csv')
